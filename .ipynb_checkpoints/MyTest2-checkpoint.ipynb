# %%
import tensorflow as tf
import os
import matplotlib.pyplot as plt
# Out:
# C:\Users\heide\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
print(tf.__version__)
# Out:
# 2.13.0-rc1

# %%
print(os.getcwd())
# Out:
# C:\Users\heide\Documents\HSLU\computer_vision

# %%
path = 'C:\\Users\\heide\\Documents\\HSLU\\Data\\Training'

# %%
path_sub = 'C:\\Users\\heide\\Documents\\HSLU\\Data_class12\\Training'

# %%
BATCH_SIZE = 32
IMG_SIZE = (160, 160)

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
    path_sub,
    validation_split=0.2,
    subset="training",
    seed=123,
    batch_size = BATCH_SIZE,
    image_size = IMG_SIZE)
# Out:
# Found 2870 files belonging to 12 classes.
# Using 2296 files for training.

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
    path_sub,
    validation_split=0.2,
    subset="validation",
    seed=123,
    batch_size = BATCH_SIZE,
    image_size = IMG_SIZE)
# Out:
# Found 2870 files belonging to 12 classes.
# Using 574 files for validation.

# %%
class_names = train_ds.class_names

# %%
print(class_names)
# Out:
# ['glioma_axial', 'glioma_coronal', 'glioma_sagittal', 'meningioma_axial', 'meningioma_coronal', 'meningioma_sagittal', 'no_tumor_axial', 'no_tumor_coronal', 'no_tumor_sagittal', 'pituitary_axial', 'pituitary_coronal', 'pituitary_sagittal']

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(12):
    ax = plt.subplot(4, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
num_classes = 12

model = tf.keras.Sequential([
  tf.keras.layers.Conv2D(32, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(32, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(32, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dense(num_classes)
])

# %%
model.compile(
  optimizer='adam',
  loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
  metrics=['accuracy'])

# %%
model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=3
)
# Out:
# Epoch 1/3
# 72/72 [==============================] - 62s 850ms/step - loss: 14.8316 - accuracy: 0.5579 - val_loss: 0.7966 - val_accuracy: 0.7631
# Epoch 2/3
# 72/72 [==============================] - 61s 840ms/step - loss: 0.3624 - accuracy: 0.8807 - val_loss: 0.5698 - val_accuracy: 0.8519
# Epoch 3/3
# 72/72 [==============================] - 60s 839ms/step - loss: 0.1137 - accuracy: 0.9660 - val_loss: 0.5922 - val_accuracy: 0.8606
